# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# | Field Name               | Description                                                                                               |
# |--------------------------|-----------------------------------------------------------------------------------------------------------|
# | VendorID                 | A code indicating the LPEP provider that provided the record.                                              |
# |                          | 1= Creative Mobile Technologies, LLC; 2= VeriFone Inc.                                                   |
# | lpep_pickup_datetime     | The date and time when the meter was engaged.                                                             |
# | lpep_dropoff_datetime    | The date and time when the meter was disengaged.                                                          |
# | Passenger_count          | The number of passengers in the vehicle. This is a driver-entered value.                                  |
# | Trip_distance            | The elapsed trip distance in miles reported by the taximeter.                                             |
# | PULocationID             | TLC Taxi Zone in which the taximeter was engaged.                                                         |
# | DOLocationID             | TLC Taxi Zone in which the taximeter was disengaged.                                                      |
# | RateCodeID               | The final rate code in effect at the end of the trip.                                                     |
# |                          | 1= Standard rate                                                                                          |
# |                          | 2= JFK                                                                                                    |
# |                          | 3= Newark                                                                                                 |
# |                          | 4= Nassau or Westchester                                                                                  |
# |                          | 5= Negotiated fare                                                                                        |
# |                          | 6= Group ride                                                                                             |
# | Store_and_fwd_flag       | This flag indicates whether the trip record was held in vehicle memory before sending to the vendor.       |
# |                          | Y= store and forward trip                                                                                 |
# |                          | N= not a store and forward trip                                                                           |
# | Payment_type             | A numeric code signifying how the passenger paid for the trip.                                            |
# |                          | 1= Credit card                                                                                            |
# |                          | 2= Cash                                                                                                   |
# |                          | 3= No charge                                                                                              |
# |                          | 4= Dispute                                                                                                |
# |                          | 5= Unknown                                                                                                |
# |                          | 6= Voided trip                                                                                            |
# | Fare_amount              | The time-and-distance fare calculated by the meter.                                                       |
# | Extra                    | Miscellaneous extras and surcharges. Currently, this only includes the $0.50 and $1 rush hour and overnight charges.|
# | MTA_tax                  | $0.50 MTA tax that is automatically triggered based on the metered rate in use.                          |
# | Improvement_surcharge    | $0.30 improvement surcharge assessed on hailed trips at the flag drop. The improvement surcharge began being levied in 2015.|
# | Tip_amount               | Tip amount – This field is automatically populated for credit card tips. Cash tips are not included.      |
# | Tolls_amount             | Total amount of all tolls paid in trip.                                                                   |
# | Total_amount             | The total amount charged to passengers. Does not include cash tips.                                       |
# | Trip_type                | A code indicating whether the trip was a street-hail or a dispatch that is automatically assigned based on the metered rate in use but can be altered by the driver.|
# |                          | 1= Street-hail                                                                                            |
# |                          | 2= Dispatch                                                                                               |

# %%
df = pd.read_parquet('data/classwork/green_tripdata_2023-01.parquet')

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2023-01-01 00:26:10   2023-01-01 00:37:11                  N
# 1             2  2023-01-01 00:51:03   2023-01-01 00:57:49                  N
# 2             2  2023-01-01 00:35:12   2023-01-01 00:41:32                  N
# 3             1  2023-01-01 00:13:14   2023-01-01 00:19:03                  N
# 4             1  2023-01-01 00:33:04   2023-01-01 00:39:02                  N
# ...         ...                  ...                   ...                ...
# 68206         2  2023-01-31 22:29:00   2023-01-31 22:42:00               None
# 68207         2  2023-01-31 22:40:00   2023-01-31 22:48:00               None
# 68208         2  2023-01-31 23:46:00   2023-02-01 00:02:00               None
# 68209         2  2023-01-31 23:01:00   2023-01-31 23:19:00               None
# 68210         2  2023-01-31 23:51:00   2023-02-01 00:07:00               None
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0             1.0           166           143              1.0           2.58
# 1             1.0            24            43              1.0           1.81
# 2             1.0           223           179              1.0           0.00
# 3             1.0            41           238              1.0           1.30
# 4             1.0            41            74              1.0           1.10
# ...           ...           ...           ...              ...            ...
# 68206         NaN            49            62              NaN        4070.82
# 68207         NaN            10           205              NaN           2.14
# 68208         NaN            66            37              NaN           3.44
# 68209         NaN           225           189              NaN           3.03
# 68210         NaN           256           140              NaN           5.82
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount ehail_fee  \
# 0            14.90    1.0      0.5        4.03           0.0      None
# 1            10.70    1.0      0.5        2.64           0.0      None
# 2             7.20    1.0      0.5        1.94           0.0      None
# 3             6.50    0.5      1.5        1.70           0.0      None
# 4             6.00    0.5      1.5        0.00           0.0      None
# ...            ...    ...      ...         ...           ...       ...
# 68206        15.70    0.0      0.0        0.00           0.0      None
# 68207         4.41    0.0      0.0        0.00           0.0      None
# 68208        16.53    0.0      0.0        3.51           0.0      None
# 68209        14.98    0.0      0.0        3.20           0.0      None
# 68210        23.65    0.0      0.0        2.00           0.0      None
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                        1.0         24.18           1.0        1.0
# 1                        1.0         15.84           1.0        1.0
# 2                        1.0         11.64           1.0        1.0
# 3                        1.0         10.20           1.0        1.0
# 4                        1.0          8.00           1.0        1.0
# ...                      ...           ...           ...        ...
# 68206                    1.0         16.70           NaN        NaN
# 68207                    1.0          5.41           NaN        NaN
# 68208                    1.0         21.04           NaN        NaN
# 68209                    1.0         19.18           NaN        NaN
# 68210                    1.0         29.40           NaN        NaN
#
#        congestion_surcharge
# 0                      2.75
# 1                      0.00
# 2                      0.00
# 3                      0.00
# 4                      0.00
# ...                     ...
# 68206                   NaN
# 68207                   NaN
# 68208                   NaN
# 68209                   NaN
# 68210                   NaN
#
# [68211 rows x 20 columns]

# %%
numerical_feats = ['passenger_count', 'trip_distance', 'fare_amount']
categorical_feats = ['PULocationID', 'DOLocationID', 'trip_type']

# %%
df2 = df[['lpep_pickup_datetime', 'lpep_dropoff_datetime'] + numerical_feats + categorical_feats].copy()

# %%
df2
# Out:
#       lpep_pickup_datetime lpep_dropoff_datetime  passenger_count  \
# 0      2023-01-01 00:26:10   2023-01-01 00:37:11              1.0
# 1      2023-01-01 00:51:03   2023-01-01 00:57:49              1.0
# 2      2023-01-01 00:35:12   2023-01-01 00:41:32              1.0
# 3      2023-01-01 00:13:14   2023-01-01 00:19:03              1.0
# 4      2023-01-01 00:33:04   2023-01-01 00:39:02              1.0
# ...                    ...                   ...              ...
# 68206  2023-01-31 22:29:00   2023-01-31 22:42:00              NaN
# 68207  2023-01-31 22:40:00   2023-01-31 22:48:00              NaN
# 68208  2023-01-31 23:46:00   2023-02-01 00:02:00              NaN
# 68209  2023-01-31 23:01:00   2023-01-31 23:19:00              NaN
# 68210  2023-01-31 23:51:00   2023-02-01 00:07:00              NaN
#
#        trip_distance  fare_amount  PULocationID  DOLocationID  trip_type
# 0               2.58        14.90           166           143        1.0
# 1               1.81        10.70            24            43        1.0
# 2               0.00         7.20           223           179        1.0
# 3               1.30         6.50            41           238        1.0
# 4               1.10         6.00            41            74        1.0
# ...              ...          ...           ...           ...        ...
# 68206        4070.82        15.70            49            62        NaN
# 68207           2.14         4.41            10           205        NaN
# 68208           3.44        16.53            66            37        NaN
# 68209           3.03        14.98           225           189        NaN
# 68210           5.82        23.65           256           140        NaN
#
# [68211 rows x 8 columns]

# %%
df2['lpep_pickup_datetime'] = pd.to_datetime(df2['lpep_pickup_datetime'])
df2['lpep_dropoff_datetime'] = pd.to_datetime(df2['lpep_dropoff_datetime'])

# %%
df2
# Out:
#       lpep_pickup_datetime lpep_dropoff_datetime  passenger_count  \
# 0      2023-01-01 00:26:10   2023-01-01 00:37:11              1.0
# 1      2023-01-01 00:51:03   2023-01-01 00:57:49              1.0
# 2      2023-01-01 00:35:12   2023-01-01 00:41:32              1.0
# 3      2023-01-01 00:13:14   2023-01-01 00:19:03              1.0
# 4      2023-01-01 00:33:04   2023-01-01 00:39:02              1.0
# ...                    ...                   ...              ...
# 68206  2023-01-31 22:29:00   2023-01-31 22:42:00              NaN
# 68207  2023-01-31 22:40:00   2023-01-31 22:48:00              NaN
# 68208  2023-01-31 23:46:00   2023-02-01 00:02:00              NaN
# 68209  2023-01-31 23:01:00   2023-01-31 23:19:00              NaN
# 68210  2023-01-31 23:51:00   2023-02-01 00:07:00              NaN
#
#        trip_distance  fare_amount  PULocationID  DOLocationID  trip_type
# 0               2.58        14.90           166           143        1.0
# 1               1.81        10.70            24            43        1.0
# 2               0.00         7.20           223           179        1.0
# 3               1.30         6.50            41           238        1.0
# 4               1.10         6.00            41            74        1.0
# ...              ...          ...           ...           ...        ...
# 68206        4070.82        15.70            49            62        NaN
# 68207           2.14         4.41            10           205        NaN
# 68208           3.44        16.53            66            37        NaN
# 68209           3.03        14.98           225           189        NaN
# 68210           5.82        23.65           256           140        NaN
#
# [68211 rows x 8 columns]

# %%
df2['duration'] = (df2['lpep_dropoff_datetime'] - df2['lpep_pickup_datetime'])
df2['duration'] = df2['duration'].dt.total_seconds() / 60

# %%
df2
# Out:
#       lpep_pickup_datetime lpep_dropoff_datetime  passenger_count  \
# 0      2023-01-01 00:26:10   2023-01-01 00:37:11              1.0
# 1      2023-01-01 00:51:03   2023-01-01 00:57:49              1.0
# 2      2023-01-01 00:35:12   2023-01-01 00:41:32              1.0
# 3      2023-01-01 00:13:14   2023-01-01 00:19:03              1.0
# 4      2023-01-01 00:33:04   2023-01-01 00:39:02              1.0
# ...                    ...                   ...              ...
# 68206  2023-01-31 22:29:00   2023-01-31 22:42:00              NaN
# 68207  2023-01-31 22:40:00   2023-01-31 22:48:00              NaN
# 68208  2023-01-31 23:46:00   2023-02-01 00:02:00              NaN
# 68209  2023-01-31 23:01:00   2023-01-31 23:19:00              NaN
# 68210  2023-01-31 23:51:00   2023-02-01 00:07:00              NaN
#
#        trip_distance  fare_amount  PULocationID  DOLocationID  trip_type  \
# 0               2.58        14.90           166           143        1.0
# 1               1.81        10.70            24            43        1.0
# 2               0.00         7.20           223           179        1.0
# 3               1.30         6.50            41           238        1.0
# 4               1.10         6.00            41            74        1.0
# ...              ...          ...           ...           ...        ...
# 68206        4070.82        15.70            49            62        NaN
# 68207           2.14         4.41            10           205        NaN
# 68208           3.44        16.53            66            37        NaN
# 68209           3.03        14.98           225           189        NaN
# 68210           5.82        23.65           256           140        NaN
#
#         duration
# 0      11.016667
# 1       6.766667
# 2       6.333333
# 3       5.816667
# 4       5.966667
# ...          ...
# 68206  13.000000
# 68207   8.000000
# 68208  16.000000
# 68209  18.000000
# 68210  16.000000
#
# [68211 rows x 9 columns]

# %%
df2 = df2.drop(['lpep_pickup_datetime', 'lpep_dropoff_datetime'], axis=1)

# %%
df2
# Out:
#        passenger_count  trip_distance  fare_amount  PULocationID  \
# 0                  1.0           2.58        14.90           166
# 1                  1.0           1.81        10.70            24
# 2                  1.0           0.00         7.20           223
# 3                  1.0           1.30         6.50            41
# 4                  1.0           1.10         6.00            41
# ...                ...            ...          ...           ...
# 68206              NaN        4070.82        15.70            49
# 68207              NaN           2.14         4.41            10
# 68208              NaN           3.44        16.53            66
# 68209              NaN           3.03        14.98           225
# 68210              NaN           5.82        23.65           256
#
#        DOLocationID  trip_type   duration
# 0               143        1.0  11.016667
# 1                43        1.0   6.766667
# 2               179        1.0   6.333333
# 3               238        1.0   5.816667
# 4                74        1.0   5.966667
# ...             ...        ...        ...
# 68206            62        NaN  13.000000
# 68207           205        NaN   8.000000
# 68208            37        NaN  16.000000
# 68209           189        NaN  18.000000
# 68210           140        NaN  16.000000
#
# [68211 rows x 7 columns]

# %%
df2['PULocationID'] = df2['PULocationID'].astype('string')
df2['DOLocationID'] = df2['DOLocationID'].astype('string')

# %%
df2.dtypes
# Out:
# passenger_count    float64
# trip_distance      float64
# fare_amount        float64
# PULocationID        string
# DOLocationID        string
# trip_type          float64
# duration           float64
# dtype: object

# %%
df2['PUDOLocationID'] = df2['PULocationID'] + '_' + df2['DOLocationID']

# %%
df2
# Out:
#        passenger_count  trip_distance  fare_amount PULocationID DOLocationID  \
# 0                  1.0           2.58        14.90          166          143
# 1                  1.0           1.81        10.70           24           43
# 2                  1.0           0.00         7.20          223          179
# 3                  1.0           1.30         6.50           41          238
# 4                  1.0           1.10         6.00           41           74
# ...                ...            ...          ...          ...          ...
# 68206              NaN        4070.82        15.70           49           62
# 68207              NaN           2.14         4.41           10          205
# 68208              NaN           3.44        16.53           66           37
# 68209              NaN           3.03        14.98          225          189
# 68210              NaN           5.82        23.65          256          140
#
#        trip_type   duration PUDOLocationID
# 0            1.0  11.016667        166_143
# 1            1.0   6.766667          24_43
# 2            1.0   6.333333        223_179
# 3            1.0   5.816667         41_238
# 4            1.0   5.966667          41_74
# ...          ...        ...            ...
# 68206        NaN  13.000000          49_62
# 68207        NaN   8.000000         10_205
# 68208        NaN  16.000000          66_37
# 68209        NaN  18.000000        225_189
# 68210        NaN  16.000000        256_140
#
# [68211 rows x 8 columns]

# %%
df2 = df2.drop(['PULocationID', 'DOLocationID'], axis=1)

# %%
df2
# Out:
#        passenger_count  trip_distance  fare_amount  trip_type   duration  \
# 0                  1.0           2.58        14.90        1.0  11.016667
# 1                  1.0           1.81        10.70        1.0   6.766667
# 2                  1.0           0.00         7.20        1.0   6.333333
# 3                  1.0           1.30         6.50        1.0   5.816667
# 4                  1.0           1.10         6.00        1.0   5.966667
# ...                ...            ...          ...        ...        ...
# 68206              NaN        4070.82        15.70        NaN  13.000000
# 68207              NaN           2.14         4.41        NaN   8.000000
# 68208              NaN           3.44        16.53        NaN  16.000000
# 68209              NaN           3.03        14.98        NaN  18.000000
# 68210              NaN           5.82        23.65        NaN  16.000000
#
#       PUDOLocationID
# 0            166_143
# 1              24_43
# 2            223_179
# 3             41_238
# 4              41_74
# ...              ...
# 68206          49_62
# 68207         10_205
# 68208          66_37
# 68209        225_189
# 68210        256_140
#
# [68211 rows x 6 columns]

# %%
df2[df2.duplicated()]
# Out:
#        passenger_count  trip_distance  fare_amount  trip_type  duration  \
# 1331               1.0           0.00         3.00        1.0  0.033333
# 3081               1.0           1.40         9.30        1.0  7.733333
# 4954               1.0           1.16         8.60        1.0  7.166667
# 5561               1.0           0.00         3.00        1.0  0.033333
# 5696               1.0           0.00         3.00        1.0  0.033333
# ...                ...            ...          ...        ...       ...
# 67221              NaN           1.01        11.00        NaN  4.000000
# 67223              NaN           0.87        11.00        NaN  4.000000
# 67295              NaN           0.85        11.96        NaN  5.000000
# 67374              NaN           0.94        11.00        NaN  6.000000
# 68070              NaN           1.01        13.30        NaN  4.000000
#
#       PUDOLocationID
# 1331         264_264
# 3081           74_41
# 4954           74_41
# 5561         264_264
# 5696         264_264
# ...              ...
# 67221        193_193
# 67223        193_193
# 67295          7_193
# 67374        193_193
# 68070        193_193
#
# [283 rows x 6 columns]

# %%
df2 = df2.drop_duplicates()

# %%
df2
# Out:
#        passenger_count  trip_distance  fare_amount  trip_type   duration  \
# 0                  1.0           2.58        14.90        1.0  11.016667
# 1                  1.0           1.81        10.70        1.0   6.766667
# 2                  1.0           0.00         7.20        1.0   6.333333
# 3                  1.0           1.30         6.50        1.0   5.816667
# 4                  1.0           1.10         6.00        1.0   5.966667
# ...                ...            ...          ...        ...        ...
# 68206              NaN        4070.82        15.70        NaN  13.000000
# 68207              NaN           2.14         4.41        NaN   8.000000
# 68208              NaN           3.44        16.53        NaN  16.000000
# 68209              NaN           3.03        14.98        NaN  18.000000
# 68210              NaN           5.82        23.65        NaN  16.000000
#
#       PUDOLocationID
# 0            166_143
# 1              24_43
# 2            223_179
# 3             41_238
# 4              41_74
# ...              ...
# 68206          49_62
# 68207         10_205
# 68208          66_37
# 68209        225_189
# 68210        256_140
#
# [67928 rows x 6 columns]

# %%
filtered_df = df2[df2.duplicated(subset=['trip_distance', 'duration'], keep=False)]
filtered_df = filtered_df.sort_values(by=['trip_distance', 'duration'])

filtered_df
# Out:
#        passenger_count  trip_distance  fare_amount  trip_type   duration  \
# 1246               1.0           0.00         3.00        1.0   0.000000
# 2015               2.0           0.00        24.00        1.0   0.000000
# 2088               1.0           0.00         3.00        1.0   0.000000
# 2346               1.0           0.00         3.70        1.0   0.000000
# 2707               2.0           0.00        40.00        2.0   0.000000
# ...                ...            ...          ...        ...        ...
# 65945              NaN          10.66        41.18        NaN  20.000000
# 42806              1.0          12.97        58.30        1.0  42.000000
# 67343              NaN          12.97        55.44        NaN  42.000000
# 32851              1.0          15.70        45.50        1.0  40.966667
# 35571              1.0          15.70        62.50        1.0  40.966667
#
#       PUDOLocationID
# 1246         226_264
# 2015           3_264
# 2088         264_264
# 2346         145_264
# 2707         255_264
# ...              ...
# 65945          74_33
# 42806        112_116
# 67343         72_138
# 32851        130_123
# 35571          75_26
#
# [17749 rows x 6 columns]

# %%
df2 = df2[(df2['fare_amount'] > 0.0) & 
          (df2['trip_distance'] > 0.0) &
          (df2['duration'] > 0.0)]

# %%
df2
# Out:
#        passenger_count  trip_distance  fare_amount  trip_type   duration  \
# 0                  1.0           2.58        14.90        1.0  11.016667
# 1                  1.0           1.81        10.70        1.0   6.766667
# 3                  1.0           1.30         6.50        1.0   5.816667
# 4                  1.0           1.10         6.00        1.0   5.966667
# 5                  1.0           2.78        17.70        1.0  17.550000
# ...                ...            ...          ...        ...        ...
# 68206              NaN        4070.82        15.70        NaN  13.000000
# 68207              NaN           2.14         4.41        NaN   8.000000
# 68208              NaN           3.44        16.53        NaN  16.000000
# 68209              NaN           3.03        14.98        NaN  18.000000
# 68210              NaN           5.82        23.65        NaN  16.000000
#
#       PUDOLocationID
# 0            166_143
# 1              24_43
# 3             41_238
# 4              41_74
# 5             41_262
# ...              ...
# 68206          49_62
# 68207         10_205
# 68208          66_37
# 68209        225_189
# 68210        256_140
#
# [64587 rows x 6 columns]

# %%
df2.loc[:,'trip_type'] = df2['trip_type'].astype('object')
df2.loc[:,'PUDOLocationID'] = df2['PUDOLocationID'].astype('object')
# Out:
# /tmp/ipykernel_1774/3956885934.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.loc[:,'trip_type'] = df2['trip_type'].astype('object')
# /tmp/ipykernel_1774/3956885934.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.loc[:,'PUDOLocationID'] = df2['PUDOLocationID'].astype('object')
# /tmp/ipykernel_1774/3956885934.py:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df2.loc[:,'PUDOLocationID'] = df2['PUDOLocationID'].astype('object')

# %%
correlation_matrix = df2.select_dtypes(exclude=object).corr(method='spearman')


# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))

# Create a heatmap of the correlation matrix, showing only below diagonal
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", mask=mask)
plt.title('Correlation')
plt.show()

# %%
df2 = df2.drop(['passenger_count'], axis=1)

# %%
df2
# Out:
#        trip_distance  fare_amount trip_type   duration PUDOLocationID
# 0               2.58        14.90       1.0  11.016667        166_143
# 1               1.81        10.70       1.0   6.766667          24_43
# 3               1.30         6.50       1.0   5.816667         41_238
# 4               1.10         6.00       1.0   5.966667          41_74
# 5               2.78        17.70       1.0  17.550000         41_262
# ...              ...          ...       ...        ...            ...
# 68206        4070.82        15.70       NaN  13.000000          49_62
# 68207           2.14         4.41       NaN   8.000000         10_205
# 68208           3.44        16.53       NaN  16.000000          66_37
# 68209           3.03        14.98       NaN  18.000000        225_189
# 68210           5.82        23.65       NaN  16.000000        256_140
#
# [64587 rows x 5 columns]

# %%
sns.countplot(df, x='trip_type')
# Out:
# <Axes: xlabel='trip_type', ylabel='count'>

# %%
df2['trip_type'].isnull().sum()
# Out:
# 4162

# %%
df2 = df2.drop(['trip_type'], axis=1)

# %%
df2 = df2[['PUDOLocationID', 'trip_distance', 'fare_amount', 'duration']]

# %%
df2
# Out:
#       PUDOLocationID  trip_distance  fare_amount   duration
# 0            166_143           2.58        14.90  11.016667
# 1              24_43           1.81        10.70   6.766667
# 3             41_238           1.30         6.50   5.816667
# 4              41_74           1.10         6.00   5.966667
# 5             41_262           2.78        17.70  17.550000
# ...              ...            ...          ...        ...
# 68206          49_62        4070.82        15.70  13.000000
# 68207         10_205           2.14         4.41   8.000000
# 68208          66_37           3.44        16.53  16.000000
# 68209        225_189           3.03        14.98  18.000000
# 68210        256_140           5.82        23.65  16.000000
#
# [64587 rows x 4 columns]

# %% [markdown]
# ## Data Exploration

# %%
sns.kdeplot(df2, x='trip_distance')
# Out:
# <Axes: xlabel='trip_distance', ylabel='Density'>

# %%
trip = df2['trip_distance']

# %%
trip.describe()
# Out:
# count     64587.000000
# mean          8.564014
# std         601.294221
# min           0.010000
# 25%           1.230000
# 50%           1.940000
# 75%           3.340000
# max      120098.840000
# Name: trip_distance, dtype: float64

# %%
np.percentile(trip, [90, 95, 99])
# Out:
# array([ 5.97  ,  7.92  , 14.7214])

# %%
sns.boxplot(df2, x="trip_distance")
# Out:
# <Axes: xlabel='trip_distance'>

# %%
# Filter the DataFrame to exclude outliers
df2 = df2[(df2['trip_distance'] <= 14)]

# %%
sns.kdeplot(df2, x='trip_distance')
# Out:
# <Axes: xlabel='trip_distance', ylabel='Density'>

# %%
sns.boxplot(df2, x="trip_distance")
# Out:
# <Axes: xlabel='trip_distance'>

# %%
df2['trip_distance'].describe()
# Out:
# count    63851.000000
# mean         2.641218
# std          2.194524
# min          0.010000
# 25%          1.220000
# 50%          1.920000
# 75%          3.270000
# max         14.000000
# Name: trip_distance, dtype: float64

# %%
sns.kdeplot(df2, x='fare_amount')
# Out:
# <Axes: xlabel='fare_amount', ylabel='Density'>

# %%
sns.boxplot(df2, x="fare_amount")
# Out:
# <Axes: xlabel='fare_amount'>

# %%
df2['fare_amount'].describe()
# Out:
# count    63851.000000
# mean        15.828775
# std         10.282814
# min          0.010000
# 25%          9.300000
# 50%         12.800000
# 75%         19.100000
# max        455.000000
# Name: fare_amount, dtype: float64

# %%
np.percentile(trip, [90, 95, 99])
# Out:
# array([ 5.97  ,  7.92  , 14.7214])

# %%
df2 = df2[df2['fare_amount'] <= 30]

# %%
sns.kdeplot(df2, x='fare_amount')
# Out:
# <Axes: xlabel='fare_amount', ylabel='Density'>

# %%
sns.boxplot(df2, x="fare_amount")
# Out:
# <Axes: xlabel='fare_amount'>

# %%
sns.kdeplot(df2, x='duration')
# Out:
# <Axes: xlabel='duration', ylabel='Density'>

# %%
df2['duration'].describe()
# Out:
# count    58257.000000
# mean        15.695134
# std         71.849083
# min          0.016667
# 25%          7.066667
# 50%         10.650000
# 75%         15.183333
# max       1438.933333
# Name: duration, dtype: float64

# %%
np.percentile(df2['duration'], [90, 95, 99])
# Out:
# array([20.39      , 24.        , 31.76466667])

# %%
df2 = df2[df2['duration'] < 27]

# %%
sns.kdeplot(df2, x='duration')
# Out:
# <Axes: xlabel='duration', ylabel='Density'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.feature_extraction import DictVectorizer
from sklearn.metr
#  'PUDOLocationID=152_262',
#  'PUDOLocationID=152_263',
#  'PUDOLocationID=152_264',
#  'PUDOLocationID=152_41',
#  'PUDOLocationID=152_42',
#  'PUDOLocationID=152_43',
#  'PUDOLocationID=152_48',
#  'PUDOLocationID=152_50',
#  'PUDOLocationID=152_60',
#  'PUDOLocationID=152_68',
#  'PUDOLocationID=152_7',
#  'PUDOLocationID=152_74',
#  'PUDOLocationID=152_75',
#  'PUDOLocationID=152_94',
#  'PUDOLocationID=153_127',
#  'PUDOLocationID=153_136',
#  'PUDOLocationID=153_153',
#  'PUDOLocationID=153_244',
#  'PUDOLocationID=154_91',
#  'PUDOLocationID=155_123',
#  'PUDOLocationID=155_155',
#  'PUDOLocationID=155_178',
#  'PUDOLocationID=155_210',
#  'PUDOLocationID=155_89',
#  'PUDOLocationID=157_102',
#  'PUDOLocationID=157_112',
#  'PUDOLocationID=157_129',
#  'PUDOLocationID=157_145',
#  'PUDOLocationID=157_157',
#  'PUDOLocationID=157_188',
#  'PUDOLocationID=157_198',
#  'PUDOLocationID=157_232',
#  'PUDOLocationID=157_256',
#  'PUDOLocationID=157_33',
#  'PUDOLocationID=157_37',
#  'PUDOLocationID=157_7',
#  'PUDOLocationID=157_79',
#  'PUDOLocationID=157_80',
#  'PUDOLocationID=157_82',
#  'PUDOLocationID=159_116',
#  'PUDOLocationID=159_119',
#  'PUDOLocationID=159_147',
#  'PUDOLocationID=159_151',
#  'PUDOLocationID=159_152',
#  'PUDOLocationID=159_159',
#  'PUDOLocationID=159_163',
#  'PUDOLocationID=159_166',
#  'PUDOLocationID=159_167',
#  'PUDOLocationID=159_168',
#  'PUDOLocationID=159_174',
#  'PUDOLocationID=159_18',
#  'PUDOLocationID=159_20',
#  'PUDOLocationID=159_212',
#  'PUDOLocationID=159_213',
#  'PUDOLocationID=159_235',
#  'PUDOLocationID=159_238',
#  'PUDOLocationID=159_24',
#  'PUDOLocationID=159_243',
#  'PUDOLocationID=159_244',
#  'PUDOLocationID=159_247',
#  'PUDOLocationID=159_254',
#  'PUDOLocationID=159_263',
#  'PUDOLocationID=159_41',
#  'PUDOLocationID=159_42',
#  'PUDOLocationID=159_69',
#  'PUDOLocationID=159_7',
#  'PUDOLocationID=159_74',
#  'PUDOLocationID=159_75',
#  'PUDOLocationID=159_78',
#  'PUDOLocationID=159_94',
#  'PUDOLocationID=160_197',
#  'PUDOLocationID=160_260',
#  'PUDOLocationID=160_95',
#  'PUDOLocationID=165_26',
#  'PUDOLocationID=165_91',
#  'PUDOLocationID=166_100',
#  'PUDOLocationID=166_107',
#  'PUDOLocationID=166_116',
#  'PUDOLocationID=166_119',
#  'PUDOLocationID=166_120',
#  'PUDOLocationID=166_127',
#  'PUDOLocationID=166_128',
#  'PUDOLocationID=166_136',
#  'PUDOLocationID=166_140',
#  'PUDOLocationID=166_141',
#  'PUDOLocationID=166_142',
#  'PUDOLocationID=166_143',
#  'PUDOLocationID=166_145',
#  'PUDOLocationID=166_151',
#  'PUDOLocationID=166_152',
#  'PUDOLocationID=166_158',
#  'PUDOLocationID=166_159',
#  'PUDOLocationID=166_161',
#  'PUDOLocationID=166_162',
#  'PUDOLocationID=166_163',
#  'PUDOLocationID=166_164',
#  'PUDOLocationID=166_166',
#  'PUDOLocationID=166_167',
#  'PUDOLocationID=166_168',
#  'PUDOLocationID=166_170',
#  'PUDOLocationID=166_179',
#  'PUDOLocationID=166_186',
#  'PUDOLocationID=166_200',
#  'PUDOLocationID=166_212',
#  'PUDOLocationID=166_220',
#  'PUDOLocationID=166_223',
#  'PUDOLocationID=166_229',
#  'PUDOLocationID=166_230',
#  'PUDOLocationID=166_231',
#  'PUDOLocationID=166_234',
#  'PUDOLocationID=166_235',
#  'PUDOLocationID=166_236',
#  'PUDOLocationID=166_237',
#  'PUDOLocationID=166_238',
#  'PUDOLocationID=166_239',
#  'PUDOLocationID=166_24',
#  'PUDOLocationID=166_241',
#  'PUDOLocationID=166_243',
#  'PUDOLocationID=166_244',
#  'PUDOLocationID=166_246',
#  'PUDOLocationID=166_247',
#  'PUDOLocationID=166_262',
#  'PUDOLocationID=166_263',
#  'PUDOLocationID=166_264',
#  'PUDOLocationID=166_265',
#  'PUDOLocationID=166_41',
#  'PUDOLocationID=166_42',
#  'PUDOLocationID=166_43',
#  'PUDOLocationID=166_47',
#  'PUDOLocationID=166_48',
#  'PUDOLocationID=166_50',
#  'PUDOLocationID=166_59',
#  'PUDOLocationID=166_68',
#  'PUDOLocationID=166_69',
#  'PUDOLocationID=166_74',
#  'PUDOLocationID=166_75',
#  'PUDOLocationID=166_78',
#  'PUDOLocationID=166_90',
#  'PUDOLocationID=167_119',
#  'PUDOLocationID=167_147',
#  'PUDOLocationID=167_152',
#  'PUDOLocationID=167_159',
#  'PUDOLocationID=167_167',
#  'PUDOLocationID=167_168',
#  'PUDOLocationID=167_247',
#  'PUDOLocationID=167_41',
#  'PUDOLocationID=167_58',
#  'PUDOLocationID=167_69',
#  'PUDOLocationID=167_74',
#  'PUDOLocationID=167_75',
#  'PUDOLocationID=167_78',
#  'PUDOLocationID=167_94',
#  'PUDOLocationID=168_116',
#  'PUDOLocationID=168_119',
#  'PUDOLocationID=168_138',
#  'PUDOLocationID=168_141',
#  'PUDOLocationID=168_147',
#  'PUDOLocationID=168_152',
#  'PUDOLocationID=168_159',
#  'PUDOLocationID=168_166',
#  'PUDOLocationID=168_167',
#  'PUDOLocationID=168_168',
#  'PUDOLocationID=168_169',
#  'PUDOLocationID=168_174',
#  'PUDOLocationID=168_18',
#  'PUDOLocationID=168_212',
#  'PUDOLocationID=168_213',
#  'PUDOLocationID=168_235',
#  'PUDOLocationID=168_239',
#  'PUDOLocationID=168_24',
#  'PUDOLocationID=168_244',
#  'PUDOLocationID=168_247',
#  'PUDOLocationID=168_248',
#  'PUDOLocationID=168_260',
#  'PUDOLocationID=168_41',
#  'PUDOLocationID=168_42',
#  'PUDOLocationID=168_43',
#  'PUDOLocationID=168_47',
#  'PUDOLocationID=168_60',
#  'PUDOLocationID=168_69',
#  'PUDOLocationID=168_74',
#  'PUDOLocationID=168_75',
#  'PUDOLocationID=169_119',
#  'PUDOLocationID=169_159',
#  'PUDOLocationID=185_259',
#  'PUDOLocationID=185_32',
#  'PUDOLocationID=185_51',
#  'PUDOLocationID=185_58',
#  'PUDOLocationID=188_123',
#  'PUDOLocationID=188_17',
#  'PUDOLocationID=188_177',
#  'PUDOLocationID=188_181',
#  'PUDOLocationID=188_188',
#  'PUDOLocationID=188_190',
#  'PUDOLocationID=188_222',
#  'PUDOLocationID=188_25',
#  'PUDOLocationID=188_26',
#  'PUDOLocationID=188_35',
#  'PUDOLocationID=188_39',
#  'PUDOLocationID=188_49',
#  'PUDOLocationID=188_61',
#  'PUDOLocationID=188_65',
#  'PUDOLocationID=188_72',
#  'PUDOLocationID=188_76',
#  'PUDOLocationID=188_80',
#  'PUDOLocationID=188_89',
#  'PUDOLocationID=188_97',
#  'PUDOLocationID=189_106',
#  'PUDOLocationID=189_112',
#  'PUDOLocationID=189_113',
#  'PUDOLocationID=189_13',
#  'PUDOLocationID=189_17',
#  'PUDOLocationID=189_181',
#  'PUDOLocationID=189_188',
#  'PUDOLocationID=189_189',
#  'PUDOLocationID=189_225',
#  'PUDOLocationID=189_25',
#  'PUDOLocationID=189_256',
#  'PUDOLocationID=189_257',
#  'PUDOLocationID=189_36',
#  'PUDOLocationID=189_40',
#  'PUDOLocationID=189_52',
#  'PUDOLocationID=189_61',
#  'PUDOLocationID=189_62',
#  'PUDOLocationID=189_65',
#  'PUDOLocationID=189_66',
#  'PUDOLocationID=189_89',
#  'PUDOLocationID=189_97',
#  'PUDOLocationID=18_136',
#  'PUDOLocationID=18_159',
#  'PUDOLocationID=18_169',
#  'PUDOLocationID=18_18',
#  'PUDOLocationID=18_20',
#  'PUDOLocationID=18_200',
#  'PUDOLocationID=18_244',
#  'PUDOLocationID=18_3',
#  'PUDOLocationID=18_69',
#  'PUDOLocationID=190_114',
#  'PUDOLocationID=190_188',
#  'PUDOLocationID=190_189',
#  'PUDOLocationID=190_225',
#  'PUDOLocationID=190_232',
#  'PUDOLocationID=190_256',
#  'PUDOLocationID=190_49',
#  'PUDOLocationID=190_61',
#  'PUDOLocationID=190_65',
#  'PUDOLocationID=190_66',
#  'PUDOLocationID=190_80',
#  'PUDOLocationID=190_89',
#  'PUDOLocationID=190_97',
#  'PUDOLocationID=191_121',
#  'PUDOLocationID=191_122',
#  'PUDOLocationID=191_130',
#  'PUDOLocationID=191_191',
#  'PUDOLocationID=191_203',
#  'PUDOLocationID=191_265',
#  'PUDOLocationID=192_121',
#  'PUDOLocationID=192_82',
#  'PUDOLocationID=192_92',
#  'PUDOLocationID=192_95',
#  'PUDOLocationID=193_107',
#  'PUDOLocationID=193_112',
#  'PUDOLocationID=193_129',
#  'PUDOLocationID=193_138',
#  'PUDOLocationID=193_140',
#  'PUDOLocationID=193_141',
#  'PUDOLocationID=193_145',
#  'PUDOLocationID=193_146',
#  'PUDOLocationID=193_161',
#  'PUDOLocationID=193_163',
#  'PUDOLocationID=193_170',
#  'PUDOLocationID=193_179',
#  'PUDOLocationID=193_186',
#  'PUDOLocationID=193_193',
#  'PUDOLocationID=193_202',
#  'PUDOLocationID=193_223',
#  'PUDOLocationID=193_226',
#  'PUDOLocationID=193_229',
#  'PUDOLocationID=193_230',
#  'PUDOLocationID=193_234',
#  'PUDOLocationID=193_237',
#  'PUDOLocationID=193_260',
#  'PUDOLocationID=193_265',
#  'PUDOLocationID=193_48',
#  'PUDOLocationID=193_7',
#  'PUDOLocationID=193_70',
#  'PUDOLocationID=193_74',
#  'PUDOLocationID=193_82',
#  'PUDOLocationID=195_181',
#  'PUDOLocationID=195_188',
#  'PUDOLocationID=195_189',
#  'PUDOLocationID=195_195',
#  'PUDOLocationID=195_224',
#  'PUDOLocationID=195_228',
#  'PUDOLocationID=195_231',
#  'PUDOLocationID=195_25',
#  'PUDOLocationID=195_26',
#  'PUDOLocationID=195_264',
#  'PUDOLocationID=195_40',
#  'PUDOLocationID=195_52',
#  'PUDOLocationID=195_65',
#  'PUDOLocationID=196_102',
#  'PUDOLocationID=196_121',
#  'PUDOLocationID=196_129',
#  'PUDOLocationID=196_130',
#  'PUDOLocationID=196_131',
#  'PUDOLocationID=196_134',
#  'PUDOLocationID=196_135',
#  'PUDOLocationID=196_138',
#  'PUDOLocationID=196_146',
#  'PUDOLocationID=196_157',
#  'PUDOLocationID=196_160',
#  'PUDOLocationID=196_173',
#  'PUDOLocationID=196_175',
#  'PUDOLocationID=196_180',
#  'PUDOLocationID=196_192',
#  'PUDOLocationID=196_193',
#  'PUDOLocationID=196_196',
#  'PUDOLocationID=196_197',
#  'PUDOLocationID=196_198',
#  'PUDOLocationID=196_216',
#  'PUDOLocationID=196_223',
#  'PUDOLocationID=196_226',
#  'PUDOLocationID=196_255',
#  'PUDOLocationID=196_258',
#  'PUDOLocationID=196_260',
#  'PUDOLocationID=196_28',
#  'PUDOLocationID=196_53',
#  'PUDOLocationID=196_56',
#  'PUDOLocationID=196_63',
#  'PUDOLocationID=196_7',
#  'PUDOLocationID=196_70',
#  'PUDOLocationID=196_82',
#  'PUDOLocationID=196_83',
#  'PUDOLocationID=196_9',
#  'PUDOLocationID=196_92',
#  'PUDOLocationID=196_93',
#  'PUDOLocationID=196_95',
#  'PUDOLocationID=196_98',
#  'PUDOLocationID=197_10',
#  'PUDOLocationID=197_130',
#  'PUDOLocationID=197_131',
#  'PUDOLocationID=197_132',
#  'PUDOLocationID=197_134',
#  'PUDOLocationID=197_135',
#  'PUDOLocationID=197_196',
#  'PUDOLocationID=197_197',
#  'PUDOLocationID=197_218',
#  'PUDOLocationID=197_95',
#  'PUDOLocationID=198_112',
#  'PUDOLocationID=198_17',
#  'PUDOLocationID=198_225',
#  'PUDOLocationID=198_255',
#  'PUDOLocationID=198_36',
#  'PUDOLocationID=198_7',
#  ...]

# %%
y = df2['duration'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
sns.kdeplot(y_pred, label='Predictions')
sns.kdeplot(y_test, label='Actual')

plt.legend()

# %%
mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 2.3725944601932114

# %%
rd = Ridge(alpha=1)
rd.fit(X_train, y_train)

y_pred2 = rd.predict(X_test)

# %%
sns.kdeplot(y_pred2, label='Predictions')
sns.kdeplot(y_test, label='Actual')

plt.legend()

# %%
mean_squared_error(y_test, y_pred2, squared=False)
# Out:
# 2.3315954516526545
